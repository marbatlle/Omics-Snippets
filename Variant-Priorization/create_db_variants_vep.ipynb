# %%
import numpy as np
import pandas as pd
import sqlite3

# %% [markdown]
# ## Importing the data

# %%
variants = pd.read_csv('Summary-VEP.tsv', sep='\t', header=0)

# %%
variants.head()
# Out:
#   chr       loc  mut gene_hgnc  \
# 0   X  41043944  T/C     USP9X
# 1   X  41056614  C/-     USP9X
# 2   X  41075906  G/C     USP9X
# 3   X  41075907  T/A     USP9X
# 4   X  44880034  -/T     KDM6A
#
#                                          tumorportal  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  AML:Near significance; BLCA:Highly significant...
#
#                                          role_driver      zygosity  var_freq  \
# 0                                   Candidate driver    Homozygous      1.00
# 1                                   Candidate driver    Homozygous      0.95
# 2                                   Candidate driver  Heterozygous      0.77
# 3                                   Candidate driver  Heterozygous      0.77
# 4  CGC:tumor suppressor; oncodriveROLE:tumor supp...  Heterozygous      0.17
#
#    coverage             gene  ... gnomAD_NFE pfam uniprot interpro  \
# 0       125  ENSG00000124486  ...      39.92  NaN     NaN      NaN
# 1       138  ENSG00000124486  ...        NaN  NaN     NaN      NaN
# 2       226  ENSG00000124486  ...        NaN  NaN     NaN      NaN
# 3       226  ENSG00000124486  ...        NaN  NaN     NaN      NaN
# 4       138  ENSG00000147050  ...        NaN  NaN     NaN      NaN
#
#   homopolymer repeatsIncohort gene_cosmic_freq mut_cosmic_freq  vscore  \
# 0         yes             NaN    665 / 6046581               0  0.1250
# 1         NaN             NaN    665 / 6046581               0  0.3125
# 2         NaN             NaN    665 / 6046581               0  0.1250
# 3         NaN             NaN    665 / 6046581               0  0.1250
# 4         yes             NaN   1019 / 6046581               0  0.2034
#
#   comments
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 38 columns]

# %%
variants.rename(columns = {'functional_impact_prediction_(PolyPhen/SIFT/CONDEL)':'functional_impact_prediction'}, inplace = True)
variants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2470 entries, 0 to 2469
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   chr                            2470 non-null   object
#  1   loc                            2470 non-null   int64
#  2   mut                            2470 non-null   object
#  3   gene_hgnc                      2470 non-null   object
#  4   tumorportal                    284 non-null    object
#  5   role_driver                    1297 non-null   object
#  6   zygosity                       2470 non-null   object
#  7   var_freq                       2470 non-null   float64
#  8   coverage                       2470 non-null   int64
#  9   gene                           2470 non-null   object
#  10  feature                        2470 non-null   object
#  11  consequence                    2470 non-null   object
#  12  functional_impact_prediction   590 non-null    object
#  13  cosmic_id                      332 non-null    object
#  14  cosmic_vep_id                  271 non-null    object
#  15  kegg_data                      1346 non-null   object
#  16  protein_position               1038 non-null   object
#  17  amino_acids                    1038 non-null   object
#  18  dbSNP                          1290 non-null   object
#  19  clinvar_acc                    399 non-null    object
#  20  clinvar_disease                399 non-null    object
#  21  clinvar_clinical_significance  399 non-null    object
#  22  variation_type                 2470 non-null   object
#  23  HGVS_cDNA                      1820 non-null   object
#  24  HGVS_protein                   1039 non-null   object
#  25  GMAF                           1060 non-null   float64
#  26  GMAF_freq                      1060 non-null   float64
#  27  gnomAD                         1135 non-null   float64
#  28  gnomAD_NFE                     1105 non-null   float64
#  29  pfam                           168 non-null    object
#  30  uniprot                        99 non-null     object
#  31  interpro                       253 non-null    object
#  32  homopolymer                    651 non-null    object
#  33  repeatsIncohort                0 non-null      float64
#  34  gene_cosmic_freq               2470 non-null   object
#  35  mut_cosmic_freq                2470 non-null   object
#  36  vscore                         2470 non-null   float64
#  37  comments                       2 non-null      object
# dtypes: float64(7), int64(2), object(29)
# memory usage: 733.4+ KB

# %% [markdown]
# ## Creating a SQLite Database

# %%
db_var = sqlite3.connect("variants_vep.db")

# %%
c = db_var.cursor()

# %%
c.execute(
    """
    CREATE TABLE variants (
	chr TEXT NOT NULL,           
	loc INTEGER NOT NULL,  
	mut TEXT,       
	gene_hgnc TEXT,                       
	tumorportal TEXT,                                 
	role_driver TEXT,                                   
	zygosity TEXT,                                      
	var_freq REAL,                                  
	coverage REAL,                                     
	gene TEXT,                                                 
	feature TEXT,                                              
	consequence TEXT,                                      
	functional_impact_prediction TEXT,   
	cosmic_id TEXT,                      
	cosmic_vep_id TEXT,                
	kegg_data TEXT,                                  
	protein_position TEXT,        
	amino_acids TEXT,                               
	dbSNP TEXT,                                          
	clinvar_acc TEXT,                                  
	clinvar_disease TEXT,                               
	clinvar_clinical_significance TEXT,           
	variation_type TEXT,                            
	HGVS_cDNA TEXT,                               
	HGVS_protein TEXT,                           
	GMAF REAL,                           
	GMAF_freq REAL,                        
	gnomAD REAL,                                        
	gnomAD_NFE TEXT,                                  
	pfam TEXT,                                             
	uniprot TEXT,                                            
	interpro TEXT,                                        
	homopolymer TEXT,                                        
	repeatsIncohort REAL,                              
	gene_cosmic_freq TEXT,                                      
	mut_cosmic_freq TEXT,                                     
	vscore REAL,                                    
	comments TEXT    
    );
     """
)

# %% [markdown]
# ## Populate the table

# %%
variants.to_sql('variants',db_var, if_exists='append', index=False)
